# %%
# !pip install pandas spacy scikit-learn
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/yoyo/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: spacy in /home/yoyo/.local/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: scikit-learn in /home/yoyo/.local/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/yoyo/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/yoyo/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/yoyo/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (4.66.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (1.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (23.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: jinja2 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (8.3.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (2.10.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (2.5.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/yoyo/.local/lib/python3.10/site-packages (from spacy) (0.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/yoyo/.local/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/yoyo/.local/lib/python3.10/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/yoyo/.local/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/yoyo/.local/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/yoyo/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/yoyo/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/yoyo/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yoyo/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yoyo/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: blis<1.2.0,>=1.1.0 in /home/yoyo/.local/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.1.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/yoyo/.local/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: rich>=10.11.0 in /home/yoyo/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/yoyo/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/yoyo/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/yoyo/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yoyo/.local/lib/python3.10/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/yoyo/.local/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/yoyo/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/yoyo/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: wrapt in /home/yoyo/.local/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/yoyo/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# /bin/bash: line 1: python: command not found

# %%
import pandas as pd
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import re

# Load spaCy model (use spacy.load instead of spacy.load)
try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    print("Downloading language model for the spaCy 'en_core_web_sm'...")
    spacy.cli.download("en_core_web_sm")
    nlp = spacy.load("en_core_web_sm")

# File paths
input_file = "screen.xlsx"  # Replace with your file path
output_file = "screening_results.csv"

# Read the Excel file
data = pd.read_excel(input_file)

# Check if required columns exist
if 'Title' in data.columns and 'Abstract' in data.columns:
    # Initialize output storage
    results = []
    
    # Predefined keywords and patterns for NLP-assisted matching
    drying_keywords = ["drying", "dehydration", "moisture"]
    coffee_keywords = ["coffee", "beans", "coffee beans"]
    math_keywords = ["model", "statistical", "regression", "mathematical", "analysis", "simulation"]
    math_patterns = r"(regression|mathematical model|statistical model|simulation|equation|analysis)"

    def analyze_abstract(abstract):
        """
        Analyze abstract text for relevance and extract mathematical approaches.
        """
        # NLP pipeline for text
        doc = nlp(abstract.lower())
        tokens = [token.text for token in doc if not token.is_stop and token.is_alpha]
        
        # Check for relevance using tokens and keywords
        is_relevant_drying = any(word in tokens for word in drying_keywords)
        is_relevant_coffee = any(word in tokens for word in coffee_keywords)
        is_relevant_math = any(word in tokens for word in math_keywords)

        # Decide inclusion
        if is_relevant_drying and is_relevant_coffee:
            if is_relevant_math:
                # Extract mathematical approaches
                matches = re.findall(math_patterns, abstract.lower())
                approach = ", ".join(set(matches)) if matches else "Unspecified"
                return "Yes", "Relevant to drying and mentions moisture or mathematical modeling.", approach
            else:
                return "No", "Mentions drying and coffee but lacks mathematical/statistical modeling.", ""
        else:
            return "No", "Not relevant to drying process of coffee beans.", ""

    # Process each row in the dataset
    for _, row in data.iterrows():
        title = str(row['Title'])
        abstract = str(row['Abstract'])
        decision, comment, approach = analyze_abstract(abstract)
        results.append({"Title": title, "Decision": decision, "Comment": comment, "Mathematical Approach": approach})
    
    # Create results DataFrame
    results_df = pd.DataFrame(results)

    # Perform clustering on abstracts for further insight
    abstracts = [str(row['Abstract']) for _, row in data.iterrows()]
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(abstracts)
    kmeans = KMeans(n_clusters=2, random_state=42).fit(X)
    results_df['Cluster'] = kmeans.labels_

    # Save to CSV
    results_df.to_csv(output_file, index=False)
    print(f"Screening completed. Results saved to {output_file}.")
else:
    print("Error: The input file does not have the required 'Title' and 'Abstract' columns.")
# Out:
# Screening completed. Results saved to screening_results.csv.
